# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from tqdm import tqdm

import pyroomacoustics as pra
import itertools
import sklearn.metrics as sk_metrics


from pathlib import Path

import shamans.utils.eval_utils as eval

# %%
metrics_angular_threshold = 15
n_sources = 3
thresholds_ang_spec = [0., 0.05, 0.1, 0.2, 0.5, 0.6, 0.8, 0.9, 1.0]

# %% [markdown]
# Used the data of experiment 3, but use threshold to find the number of sources.

# %%
# merge all the csv fo the experiments 1 for different runs
def merge_csvs_and_get_dataframe(exp_id, path_to_results):
    all_filenames = [i for i in path_to_results.glob(f'*_exp-{exp_id}_run-*.csv')]
    combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
    combined_csv.to_csv(path_to_results / f"experiment_results_exp-{exp_id}_all_runs.csv", index=False, encoding='utf-8-sig')
    return combined_csv

def merge_pickles_and_get_dict(exp_id, path_to_results):
    all_filenames = [i for i in path_to_results.glob(f'*_exp-{exp_id}_run-*_with_ang_specs.pkl')]
    combined_dicts = []
    for filename in tqdm(all_filenames):
        with open(filename, 'rb') as f:
            combined_dicts += pickle.load(f)
    with open(path_to_results / f"experiment_results_exp-{exp_id}_all_runs_with_ang_specs.pkl", 'wb') as f:
        pickle.dump(combined_dicts, f)
    return combined_dicts

# %%
# load data
exp_id = 3
path_to_results = Path('results/')
exp_df = merge_csvs_and_get_dataframe(exp_id, path_to_results)
ang_specs = merge_pickles_and_get_dict(exp_id, path_to_results)
# Out:
# 100%|██████████| 20/20 [00:03<00:00,  5.33it/s]

# %%
exp_df.columns
# Out:
# Index(['exp_name', 'time', 'record_id', 'num_srcs', 'src_ids', 'doas_est_idx',
#        'doas_ref_idx', 'doas_ref_az', 'doas_est_az', 'doas_ref_el',
#        'doas_est_el', 'errors', 'speech_files', 'frame_id', 'target_doa',
#        'n_sources', 'duration', 'snr', 'noise_type', 'rt60', 'mc_seed',
#        'method_id', 'loc_method', 'freq_min', 'freq_max', 'sv_method', 'nObs',
#        'seed', 'sv_normalization'],
#       dtype='object')

# %%
exp_df['loc_method_simple'] = exp_df['loc_method'].apply(lambda x: x.split('-')[0])

best_seed = 666
# rename ref_8 and alg_6 to ref and alg
exp_df = exp_df.assign(sv_model=exp_df['sv_method'] + '_' + exp_df['nObs'].astype(str))
exp_df = exp_df.assign(loc_algo=exp_df['loc_method'].str[:3])
exp_df['sv_model'] = exp_df['sv_model'].str.replace('ref_8', 'ref')
exp_df['sv_model'] = exp_df['sv_model'].str.replace('alg_8', 'alg')
exp_df.loc[exp_df['sv_model'] == 'ref', 'seed'] = 666
exp_df.loc[exp_df['sv_model'] == 'alg', 'seed'] = 666

exp_df = exp_df[
    (exp_df['n_sources'] == n_sources)
    & (exp_df['loc_method'].isin([
        'srp_phat', 
        'music_s-1', 
        'music_s-4', 
        'music_s-5', 
        'music_s-6', 
        'alpha-2.0_beta-2_eps-1E-3_iter-500',
        'alpha-1.2_beta-2_eps-1E-3_iter-500',
        'alpha-1.2_beta-1_eps-1E-3_iter-500',
        'alpha-1.2_beta-0_eps-1E-3_iter-500',
        ]))
    # & (exp_df['sv_method'].isin(['ref', 'alg']))
    & (exp_df['seed'] == 666)
    & (exp_df['duration'] == 1)
    & (exp_df['rt60'] > -1)
]
print(len(exp_df))

# laod picke file with the ground truth
with open(path_to_results / 'experiment_results_exp-3_all_runs_with_ang_specs.pkl', 'rb') as f:
    list_of_ang_specs = pickle.load(f)
    
print(exp_df.shape)
print(len(list_of_ang_specs))

doa_grid_rad = np.deg2rad(np.arange(0, 360, 6))
# Out:
# 8820
# (8820, 32)
# 58860

# %%
unique_frame_ids = exp_df['frame_id'].unique()
print(len(unique_frame_ids))
unique_method_ids = exp_df['method_id'].unique()
print(len(unique_method_ids))
# Out:
# 60
# 49

# %%
print(unique_method_ids)
# Out:
# ['music_s-1_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True'
#  'music_s-1_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True'
#  'music_s-1_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True'
#  'music_s-1_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True'
#  'music_s-1_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True'
#  'music_s-1_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True'
#  'music_s-1_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True'
#  'srp_phat_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True'
#  'srp_phat_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True'
#  'srp_phat_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True'
#  'srp_phat_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True'
#  'srp_phat_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True'
#  'srp_phat_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True'
#  'srp_phat_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True'
#  'music_s-4_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True'
#  'music_s-4_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True'
#  'music_s-4_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True'
#  'music_s-4_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True'
#  'music_s-4_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True'
#  'music_s-4_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True'
#  'music_s-4_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True'
#  'alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True'
#  'alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True'
#  'alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True'
#  'alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True'
#  'alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True'
#  'alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True'
#  'alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True'
#  'alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True'
#  'alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True'
#  'alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True'
#  'alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True'
#  'alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True'
#  'alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True'
#  'alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True'
#  'alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True'
#  'alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True'
#  'alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True'
#  'alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True'
#  'alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True'
#  'alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True'
#  'alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True'
#  'alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True'
#  'alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True'
#  'alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True'
#  'alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True'
#  'alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True'
#  'alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True'
#  'alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True']

# %%
# initialize the dict with the frame ids
ang_specs_dicts = {}
for frame_id in unique_frame_ids:
    ang_specs_dicts[frame_id] = {}
    for method_id in unique_method_ids:
        ang_specs_dicts[frame_id][method_id] = None

for d in tqdm(list_of_ang_specs):
    if not d['frame_id'] in unique_frame_ids:
        continue
    if not d['method_id'] in unique_method_ids:
        continue
    # add the method id to the frame id
    ang_specs_dicts[d['frame_id']][d['method_id']] = d
    
# check if all the frames are there
missing_frames = []
retrieve_frames = []
for frame_id in unique_frame_ids:
    for method_id in unique_method_ids:
        if ang_specs_dicts[frame_id][method_id] is None:
            missing_frames.append((frame_id))
        else:
            retrieve_frames.append((frame_id))
            
print("Missing:", len(np.unique(missing_frames)))
print(np.unique(missing_frames))
print("Retrieved:", len(np.unique(retrieve_frames)))
print(np.unique(retrieve_frames))
# Out:
# 100%|██████████| 58860/58860 [00:00<00:00, 168546.11it/s]
# Missing: 0
# []
# Retrieved: 60
# ['nSrc-3_doas-[ 2 47 55]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-10'
#  'nSrc-3_doas-[ 2 47 55]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-10'
#  'nSrc-3_doas-[ 2 47 55]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-10'
#  'nSrc-3_doas-[ 2 51  3]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-1'
#  'nSrc-3_doas-[ 2 51  3]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-1'
#  'nSrc-3_doas-[ 2 51  3]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-1'
#  'nSrc-3_doas-[ 7 54 41]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-6'
#  'nSrc-3_doas-[ 7 54 41]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-6'
#  'nSrc-3_doas-[ 7 54 41]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-6'
#  'nSrc-3_doas-[11 15 56]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-16'
#  'nSrc-3_doas-[11 15 56]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-16'
#  'nSrc-3_doas-[11 15 56]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-16'
#  'nSrc-3_doas-[14 58  2]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-14'
#  'nSrc-3_doas-[14 58  2]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-14'
#  'nSrc-3_doas-[14 58  2]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-14'
#  'nSrc-3_doas-[17 57 54]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-7'
#  'nSrc-3_doas-[17 57 54]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-7'
#  'nSrc-3_doas-[17 57 54]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-7'
#  'nSrc-3_doas-[40 42 44]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-5'
#  'nSrc-3_doas-[40 42 44]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-5'
#  'nSrc-3_doas-[40 42 44]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-5'
#  'nSrc-3_doas-[40 56 16]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-9'
#  'nSrc-3_doas-[40 56 16]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-9'
#  'nSrc-3_doas-[40 56 16]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-9'
#  'nSrc-3_doas-[42 40 45]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-0'
#  'nSrc-3_doas-[42 40 45]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-0'
#  'nSrc-3_doas-[42 40 45]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-0'
#  'nSrc-3_doas-[47  9 14]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-2'
#  'nSrc-3_doas-[47  9 14]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-2'
#  'nSrc-3_doas-[47  9 14]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-2'
#  'nSrc-3_doas-[48 47 50]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-18'
#  'nSrc-3_doas-[48 47 50]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-18'
#  'nSrc-3_doas-[48 47 50]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-18'
#  'nSrc-3_doas-[48 57  6]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-19'
#  'nSrc-3_doas-[48 57  6]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-19'
#  'nSrc-3_doas-[48 57  6]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-19'
#  'nSrc-3_doas-[48 59  4]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-4'
#  'nSrc-3_doas-[48 59  4]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-4'
#  'nSrc-3_doas-[48 59  4]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-4'
#  'nSrc-3_doas-[49 16  9]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-3'
#  'nSrc-3_doas-[49 16  9]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-3'
#  'nSrc-3_doas-[49 16  9]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-3'
#  'nSrc-3_doas-[49 50  9]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-12'
#  'nSrc-3_doas-[49 50  9]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-12'
#  'nSrc-3_doas-[49 50  9]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-12'
#  'nSrc-3_doas-[50 17 43]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-13'
#  'nSrc-3_doas-[50 17 43]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-13'
#  'nSrc-3_doas-[50 17 43]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-13'
#  'nSrc-3_doas-[50 40 16]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-15'
#  'nSrc-3_doas-[50 40 16]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-15'
#  'nSrc-3_doas-[50 40 16]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-15'
#  'nSrc-3_doas-[51 43 19]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-11'
#  'nSrc-3_doas-[51 43 19]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-11'
#  'nSrc-3_doas-[51 43 19]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-11'
#  'nSrc-3_doas-[54 19 16]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-17'
#  'nSrc-3_doas-[54 19 16]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-17'
#  'nSrc-3_doas-[54 19 16]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-17'
#  'nSrc-3_doas-[55 59 50]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.0_mc-8'
#  'nSrc-3_doas-[55 59 50]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.123_mc-8'
#  'nSrc-3_doas-[55 59 50]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-8']

# %%
assert len(ang_specs_dicts.keys()) == len(unique_frame_ids), f"{len(ang_specs_dicts.keys())} != {len(unique_frame_ids)}"

# %%
def detect_peaks(values):
    # make circular
    n_points = len(values)
    val_ext = np.append(values, values[:10])

    # run peak finding
    indexes = pra.doa.detect_peaks(val_ext, show=False) % n_points
    candidates = np.unique(indexes)  # get rid of duplicates, if any
    return candidates

# %%
df_results = pd.DataFrame()

for thr in thresholds_ang_spec:
    
    for frame_id in tqdm(unique_frame_ids, desc='Iterating over frames for thr={}'.format(thr)):
        
        for method_id in unique_method_ids:
            
            ang_spec = ang_specs_dicts[frame_id][method_id]['ang_spec']
            assert len(ang_spec.shape) == 2
            assert ang_spec.shape[0] == len(doa_grid_rad)
            ang_spec = np.mean(np.array(ang_spec), -1)
            ang_spec = ang_spec / np.max(ang_spec)
            
            # set the threshold
            ang_spec[ang_spec < thr] = 0
            
            # find peaks
            peaks = detect_peaks(ang_spec)     
            
            df_ = pd.DataFrame({
                'frame_id': frame_id,
                "method_id": method_id,
                'thresholds_ang_spec': thr,
                'peaks_locations': peaks.tolist(),
                'peaks_ids' : [f'p{i}' for i in range(len(peaks))],
                'n_peaks': len(peaks)
            })
            df_results = pd.concat([df_results, df_], ignore_index=True)
        
print(len(df_results))
# Out:
# Iterating over frames for thr=0.0: 100%|██████████| 60/60 [00:01<00:00, 40.03it/s]
# Iterating over frames for thr=0.05: 100%|██████████| 60/60 [00:02<00:00, 25.70it/s]
# Iterating over frames for thr=0.1: 100%|██████████| 60/60 [00:03<00:00, 19.48it/s]
# Iterating over frames for thr=0.2: 100%|██████████| 60/60 [00:03<00:00, 16.61it/s]
# Iterating over frames for thr=0.5: 100%|██████████| 60/60 [00:03<00:00, 15.12it/s]
# Iterating over frames for thr=0.6: 100%|██████████| 60/60 [00:04<00:00, 13.64it/s]
# Iterating over frames for thr=0.8: 100%|██████████| 60/60 [00:04<00:00, 12.51it/s]
# Iterating over frames for thr=0.9: 100%|██████████| 60/60 [00:05<00:00, 11.35it/s]
# Iterating over frames for thr=1.0: 100%|██████████| 60/60 [00:05<00:00, 11.95it/s]
# 100697

# %%
# merge the results_df with the exp_df on the frame_id and method_id
df_merge = exp_df.merge(df_results, on=['frame_id', 'method_id'])
print(len(df_merge))
# Out:
# 302091

# %%
results_thr_list = []

for frame_id in tqdm(unique_frame_ids, desc='Iterating over frames'):
    for method_id in unique_method_ids:
        
        df_ = df_merge.loc[
            (df_merge['frame_id'] == frame_id) 
            & (df_merge['method_id'] == method_id)
        ]
        
        thrs = df_['thresholds_ang_spec'].unique()
        
        for thr in thrs:
            
            n_sources = df_.loc[df_['thresholds_ang_spec'] == thr, 'n_sources'].unique()
            
            assert len(n_sources) == 1
            n_sources = n_sources[0]
            
            estimated_peaks_loc = df_.loc[df_['thresholds_ang_spec'] == thr, 'peaks_locations'].unique()
            estimated_azimuths = np.rad2deg(doa_grid_rad[estimated_peaks_loc])
            target_azimuths = np.rad2deg(df_.loc[df_['thresholds_ang_spec'] == thr, 'doas_ref_az'].unique())
            
            n_estimated = len(estimated_azimuths)
            n_target = len(target_azimuths)
            assert n_target == n_sources, f"{n_target} != {n_sources} \n {frame_id}"
            
            metrics = eval.compute_metrics(estimated_azimuths, target_azimuths, metrics_angular_threshold, np.rad2deg(doa_grid_rad))
            
            # print(metrics['TP'], metrics['FP'], metrics['FN'], metrics['TN'])
            
            # check that tpr and fpr are not nans
            if np.isnan(metrics['tpr']) or np.isnan(metrics['fpr']):
                print(frame_id)
                print(estimated_azimuths)
                print(target_azimuths)
                print(n_sources)
                print(method_id)
                print(df_.loc[df_['thresholds_ang_spec'] == thr])
                raise ValueError('TPR or FPR is nan')
            
            
            if len(target_azimuths) > n_sources:
                print(frame_id)
                print(estimated_azimuths)
                print(target_azimuths)
                print(n_sources)
                print(method_id)
                print(df_.loc[df_['thresholds_ang_spec'] == thr])
                raise ValueError('True positives greater than n_sources')
            
            metrics['frame_id'] = frame_id
            metrics['method_id'] = method_id
            metrics['metrics_angular_threshold'] = metrics_angular_threshold
            metrics['thresholds_ang_spec'] = float(thr)
            
            results_thr_list.append(metrics)
        
df_results_thr_ = pd.DataFrame(results_thr_list)
# Out:
# Iterating over frames:  87%|████████▋ | 52/60 [01:10<00:10,  1.34s/it]

# %%
df_results_thr = df_results_thr_.merge(df_merge, on=['frame_id', 'method_id', 'thresholds_ang_spec'])
df_results_thr[:100].to_csv('asd.csv', index=False)
len(df_results_thr)

print(len(df_merge['method_id'].unique()))
print(len(df_results_thr_['method_id'].unique()))
print(len(df_results_thr['method_id'].unique()))
# Out:
# 49
# 49
# 49

# %%
thrs = np.sort(df_['thresholds_ang_spec'].unique())[::-1]
print(thrs)

auc_df = pd.DataFrame()

for rt60 in df_results_thr['rt60'].unique():

    # plt.figure(figsize=(8, 6))
    # plt.title(f'ROC curve for RT60={rt60}')
    
    for method_id in unique_method_ids:

        tpr_list = []
        fpr_list = []
        f1_list = []
        
        for t, thr in enumerate(thrs):
            
            df_ = df_results_thr.loc[
                    (df_results_thr['method_id'] == method_id)
                    & (df_results_thr['rt60'] == rt60)
                ]
            
            loc_method = df_['loc_method'].unique()
            sv_method = df_['sv_method'].unique()
            assert len(sv_method) == 1
            sv_method = sv_method[0]
            assert len(loc_method) == 1
            loc_method = loc_method[0]
            nObs = df_['nObs'].unique()
            assert len(nObs) == 1
            nObs = nObs[0]
                                    
            # micro-averaging over the frames
            TP = FP = FN = TN = 0.0
            tpr_list_ = []
            fpr_list_ = []
                        
            for frame_id in df_['frame_id'].unique():
                
                df__ = df_[(df_['frame_id'] == frame_id)]
                    
                TPs = df__[df__['thresholds_ang_spec'] == thr]['TP'].unique()
                FPs = df__[df__['thresholds_ang_spec'] == thr]['FP'].unique()
                FNs = df__[df__['thresholds_ang_spec'] == thr]['FN'].unique()
                TNs = df__[df__['thresholds_ang_spec'] == thr]['TN'].unique()
                peaks_id = df__[df__['thresholds_ang_spec'] == thr]['peaks_ids'].values
                
                tpr = df__[df__['thresholds_ang_spec'] == thr]['tpr'].unique()
                fpr = df__[df__['thresholds_ang_spec'] == thr]['fpr'].unique()
                
                # check that tpr and fpr are not nans
                if np.isnan(TPs) or np.isnan(FPs) or np.isnan(FNs) or np.isnan(TNs):
                    print(frame_id)
                    print(peaks_id)
                    print(TPs, FPs, FNs, TNs)
                    print(method_id)
                    print(df__)
                    raise ValueError('TPR or FPR is nan')
                
                assert len(np.unique(TPs)) == len(np.unique(FPs)) == len(np.unique(FNs)) == len(np.unique(TNs)) == 1
                assert len(np.unique(tpr)) == len(np.unique(fpr)) == 1
                
                TP += TPs[0]
                FP += FPs[0]
                FN += FNs[0]
                TN += TNs[0]
                                            
                tpr_list_.append(tpr[0])
                fpr_list_.append(fpr[0])
                
            
            # import ipdb; ipdb.set_trace()
            tpr = TP / (TP + FN)
            fpr = FP / (FP + TN)
            f1 = 2 * TP / (2 * TP + FP + FN)
            
            # tpr_list.append(tpr)
            # fpr_list.append(fpr)
            # f1_list.append(f1)
            
            tpr_list.append(np.mean(tpr_list_))
            fpr_list.append(np.mean(fpr_list_))
            
        # plot ROC curve
        
        tpr_list = [0] + tpr_list + [1]
        fpr_list = [0] + fpr_list + [1]
        
        label = method_id
        
        # compute AUC
        auc = np.trapezoid(tpr_list, fpr_list)
        auc_sk = sk_metrics.auc(fpr_list, tpr_list)
        
        auc_df_ = pd.DataFrame({
            'loc_method': loc_method,
            'sv_method': sv_method,
            'nObs': nObs,
            'method_id': method_id,
            'auc': auc,
            'auc_sk': auc_sk,
            'rt60': rt60,
            'ang_spec_thr': metrics_angular_threshold
        }, index=[0])
        auc_df = pd.concat([auc_df, auc_df_], ignore_index=True)
        
        print(f'AUC for {label} is {auc:0.3f}')
        
        label = loc_method + ' ' + sv_method + ' ' + str(nObs)
        # if 'alpha' in loc_method:
        #     plt.step(fpr_list, tpr_list, label=label, linestyle='--', where='pre')
        # else:
        #     plt.step(fpr_list, tpr_list, label=label, where='pre')

        
    # plt.legend(loc='lower right')
    # plt.show()
# Out:
# [1.   0.9  0.8  0.6  0.5  0.2  0.1  0.05 0.  ]
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.798
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.716
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.832
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.827
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.813
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.835
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.800
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.819
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.741
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.835
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.875
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.848
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.832
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.830
# AUC for srp_phat_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.767
# AUC for srp_phat_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.692
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.754
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.761
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.768
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.756
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.761
# AUC for music_s-1_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.763
# AUC for music_s-1_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.607
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.690
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.739
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.737
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.742
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.746
# AUC for music_s-4_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.898
# AUC for music_s-4_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.562
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.728
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.743
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.774
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.833
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.844
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.794
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.711
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.826
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.842
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.819
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.822
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.792
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.787
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.728
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.824
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.841
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.819
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.827
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.790
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.800
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.720
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.817
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.830
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.813
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.833
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.807
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.818
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.745
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.827
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.881
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.843
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.844
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.828
# AUC for srp_phat_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.762
# AUC for srp_phat_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.684
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.745
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.767
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.764
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.757
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.759
# AUC for music_s-1_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.760
# AUC for music_s-1_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.599
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.705
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.726
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.745
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.748
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.742
# AUC for music_s-4_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.869
# AUC for music_s-4_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.595
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.712
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.754
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.791
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.834
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.854
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.797
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.718
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.820
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.840
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.810
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.824
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.804
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.795
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.730
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.808
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.840
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.823
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.828
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.810
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.805
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.703
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.778
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.820
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.836
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.833
# AUC for alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.804
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.830
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.724
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.799
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.828
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.859
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.836
# AUC for alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.841
# AUC for srp_phat_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.752
# AUC for srp_phat_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.680
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.748
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.766
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.762
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.756
# AUC for srp_phat_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.750
# AUC for music_s-1_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.755
# AUC for music_s-1_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.613
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.698
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.724
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.743
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.765
# AUC for music_s-1_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.748
# AUC for music_s-4_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.861
# AUC for music_s-4_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.621
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.706
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.720
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.782
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.836
# AUC for music_s-4_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.850
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.810
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.700
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.766
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.822
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.845
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.832
# AUC for alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.799
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_ref_nObs-8_seed-13_norm-True is 0.797
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_alg_nObs-8_seed-13_norm-True is 0.694
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-8_seed-666_norm-True is 0.765
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-16_seed-666_norm-True is 0.819
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True is 0.834
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-64_seed-666_norm-True is 0.836
# AUC for alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-128_seed-666_norm-True is 0.811

# %%
hue_order = [
    'srp_phat', 'music_s-1', 'music_s-4', 'music_s-5',
    'alpha-1.2_beta-0_eps-1E-3_iter-500',
    'alpha-1.2_beta-1_eps-1E-3_iter-500',
    'alpha-1.2_beta-2_eps-1E-3_iter-500',
    'alpha-2.0_beta-2_eps-1E-3_iter-500',
]
sns.catplot(data=auc_df, hue='loc_method', y='auc', x='sv_method', col='rt60', kind='bar', sharey=True, hue_order=hue_order)

# %%
hue_order = [
    'srp_phat', 'music_s-1', 'music_s-4',
    # 'alpha-1.2_beta-0_eps-1E-3_iter-500',
    'alpha-1.2_beta-1_eps-1E-3_iter-500',
    # 'alpha-1.2_beta-2_eps-1E-3_iter-500',
    # 'alpha-2.0_beta-2_eps-1E-3_iter-500',
]

# if sv_method is gp-steerer then use nObs = XXX
auc_df_ = auc_df[
    (auc_df['sv_method'].isin(['ref', 'alg']))
    | (auc_df['sv_method'].isin(['gp-steerer']) & (auc_df['nObs'] == 32))
]

ax = sns.catplot(data=auc_df_, hue='loc_method', y='auc', x='sv_method', col='rt60', kind='bar', sharey=True, hue_order=hue_order)
plt.suptitle(f'AUC for different methods with GP-Steerer fit on nObs=32\n n_sources = {n_sources}', y=1.05)
# Out:
# Text(0.5, 1.05, 'AUC for different methods with GP-Steerer fit on nObs=32\n n_sources = 6')

# %% [markdown]
# # Plot angular spectrograms

# %%
frame_id = unique_frame_ids[20]
print(frame_id)

curr_df = df_results_thr[
    df_results_thr['frame_id'] == frame_id
]
true_azimuths = curr_df['doas_ref_idx'].unique()
print(true_azimuths)

method_ids = auc_df_['method_id'].unique()


for method_id in method_ids:
    
    if not 'gp-steerer' in method_id:
        continue
    
    print(method_id)
    
    ang_spec = ang_specs_dicts[frame_id][method_id]['ang_spec']
    ang_spec = ang_spec.mean(-1)
    ang_spec /= np.max(ang_spec) 
    
    label = method_id[:7]
    
    if 'srp' in method_id:
        plt.plot(ang_spec, '--', label=label)
    elif 'music' in method_id:
        plt.plot(ang_spec, '-.', label=label)
    else:
        plt.plot(ang_spec, '-', label=label)
        
for az in true_azimuths:
    plt.axvline(x=az)
    
plt.legend()
plt.show()
# Out:
# nSrc-6_doas-[49 50  9 18 14 15]_type-speech-duration-1.0-snr-20_noise-awgn_reverb-0.273_mc-12
# [49 50  9 18 14 15]
# alpha-1.2_beta-0_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True
# alpha-2.0_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True
# srp_phat_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True
# music_s-1_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True
# music_s-4_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True
# alpha-1.2_beta-1_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True
# alpha-1.2_beta-2_eps-1E-3_iter-500_freqs-[200, 4000]_gp-steerer_nObs-32_seed-666_norm-True
