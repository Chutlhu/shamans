# %%
import numpy as np
from torchaudio.datasets import VCTK_092
import matplotlib.pyplot as plt
import soundfile as sf
import torch

# %%
dataset = VCTK_092("/media/dicarlod/SSD_3/Datasets/", download=True, mic_id='mic1')

# %%
for i in range(20):
    waveform, sample_rate, transcript, speaker_id, utterance_id = dataset[i]
    # print(f"Waveform shape: {waveform.shape}, Sample rate: {sample_rate}, type: {type(waveform)}")
    print(f"{i} Speaker ID: {speaker_id}, Utterance ID: {utterance_id}")
    # print("-" * 40)

    plt.figure(figsize=(10, 2))
    time = np.arange(waveform.shape[1]) / sample_rate
    plt.plot(time, waveform[0].numpy())
    plt.show()

    # sf.write(f"{i}_vctk_{speaker_id}_{utterance_id}.wav", waveform[0].numpy(), sample_rate)
# Out:
# 0 Speaker ID: p225, Utterance ID: 001
# 1 Speaker ID: p225, Utterance ID: 002
# 2 Speaker ID: p225, Utterance ID: 003
# 3 Speaker ID: p225, Utterance ID: 004
# 4 Speaker ID: p225, Utterance ID: 005
# 5 Speaker ID: p225, Utterance ID: 006
# 6 Speaker ID: p225, Utterance ID: 007
# 7 Speaker ID: p225, Utterance ID: 008
# 8 Speaker ID: p225, Utterance ID: 009
# 9 Speaker ID: p225, Utterance ID: 010
# 10 Speaker ID: p225, Utterance ID: 011
# 11 Speaker ID: p225, Utterance ID: 012
# 12 Speaker ID: p225, Utterance ID: 013
# 13 Speaker ID: p225, Utterance ID: 014
# 14 Speaker ID: p225, Utterance ID: 016
# 15 Speaker ID: p225, Utterance ID: 017
# 16 Speaker ID: p225, Utterance ID: 018
# 17 Speaker ID: p225, Utterance ID: 019
# 18 Speaker ID: p225, Utterance ID: 020
# 19 Speaker ID: p225, Utterance ID: 021

# %%
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=1,
    shuffle=True,
    num_workers=0,  # Set to 0 for simplicity, adjust as needed
)

# %%
for i, data in enumerate(dataset):
    pass
print(i)
# Out:
# 44282

# %%
dataset[1][0].shape
dataset[0][0].shape
# Out:
# torch.Size([1, 98473])

# %%
i
# Out:
# 44282

# %%
data
# Out:
# (tensor([[0.0018, 0.0017, 0.0017,  ..., 0.0014, 0.0017, 0.0013]]),
#  48000,
#  'I saw one man vote five times.\n',
#  's5',
#  '400')

# %%
len(dataset)
# Out:
# 44283
